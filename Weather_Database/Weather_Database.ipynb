# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                         # "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | karaton
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | nakhodka
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | minot
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | pisco
# Processing Record 16 of Set 1 | grand gaube
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | mora
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | constitucion
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | vizinga
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | aykhal
# Processing Record 35 of Set 1 | vardo
# Processing Record 36 of Set 1 | klaksvik
# Processing Record 37 of Set 1 | srednekolymsk
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | sao filipe
# Processing Record 45 of Set 1 | ishigaki
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | arkhipo-osipovka
# Processing Record 48 of Set 1 | kysyl-syr
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | vostok
# Processing Record 2 of Set 2 | bredy
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | aswan
# Processing Record 5 of Set 2 | bubaque
# Processing Record 6 of Set 2 | miramar
# Processing Record 7 of Set 2 | marsa matruh
# Processing Record 8 of Set 2 | moba
# Processing Record 9 of Set 2 | poum
# Processing Record 10 of Set 2 | la plata
# Processing Record 11 of Set 2 | vestmannaeyjar
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | muhlhausen
# Processing Record 16 of Set 2 | oktyabrskiy
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | vao
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | kpagouda
# City not found. Skipping...
# Processing Record 24 of Set 2 | clinton
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | sao jose da coroa grande
# Processing Record 27 of Set 2 | notre-dame-du-lac
# Processing Record 28 of Set 2 | leningradskiy
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | san quintin
# Processing Record 32 of Set 2 | dingle
# Processing Record 33 of Set 2 | buala
# Processing Record 34 of Set 2 | tura
# Processing Record 35 of Set 2 | gazanjyk
# Processing Record 36 of Set 2 | katobu
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | pakxan
# Processing Record 40 of Set 2 | assiniboia
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | bone
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | sicamous
# Processing Record 46 of Set 2 | havoysund
# Processing Record 47 of Set 2 | zahesi
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | alofi
# Processing Record 50 of Set 2 | ahuimanu
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | hokitika
# Processing Record 4 of Set 3 | sangar
# Processing Record 5 of Set 3 | roma
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | pingliang
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | asfi
# Processing Record 11 of Set 3 | hastings
# Processing Record 12 of Set 3 | tabuk
# Processing Record 13 of Set 3 | celestun
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | port shepstone
# Processing Record 16 of Set 3 | havre-saint-pierre
# Processing Record 17 of Set 3 | matameye
# City not found. Skipping...
# Processing Record 18 of Set 3 | vila velha
# Processing Record 19 of Set 3 | naryan-mar
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | makokou
# Processing Record 22 of Set 3 | marsabit
# Processing Record 23 of Set 3 | rivne
# Processing Record 24 of Set 3 | mayumba
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | belaya gora
# Processing Record 27 of Set 3 | pacifica
# Processing Record 28 of Set 3 | yershov
# Processing Record 29 of Set 3 | ust-ishim
# Processing Record 30 of Set 3 | inhambane
# Processing Record 31 of Set 3 | huilong
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | redcliffe
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | nome
# Processing Record 36 of Set 3 | kilindoni
# Processing Record 37 of Set 3 | sinnamary
# Processing Record 38 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 39 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 3 | waipawa
# Processing Record 41 of Set 3 | ostersund
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | lucapa
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | sobradinho
# Processing Record 46 of Set 3 | beringovskiy
# Processing Record 47 of Set 3 | candido mendes
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | nicoya
# Processing Record 50 of Set 3 | goure
# Processing Record 1 of Set 4 | kerman
# Processing Record 2 of Set 4 | hobyo
# Processing Record 3 of Set 4 | itoman
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | charters towers
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | kashi
# Processing Record 8 of Set 4 | baker city
# Processing Record 9 of Set 4 | anchorage
# Processing Record 10 of Set 4 | jiayuguan
# Processing Record 11 of Set 4 | beruni
# City not found. Skipping...
# Processing Record 12 of Set 4 | oriximina
# Processing Record 13 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 4 | nago
# Processing Record 16 of Set 4 | talnakh
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | shingu
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | nhulunbuy
# Processing Record 22 of Set 4 | eureka
# Processing Record 23 of Set 4 | kailua
# Processing Record 24 of Set 4 | kununurra
# Processing Record 25 of Set 4 | plettenberg bay
# Processing Record 26 of Set 4 | jevnaker
# Processing Record 27 of Set 4 | toyooka
# Processing Record 28 of Set 4 | sydney
# Processing Record 29 of Set 4 | port hardy
# Processing Record 30 of Set 4 | bloomfield
# Processing Record 31 of Set 4 | haines junction
# Processing Record 32 of Set 4 | batagay-alyta
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | iquitos
# Processing Record 35 of Set 4 | ambanja
# Processing Record 36 of Set 4 | kruisfontein
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | asau
# Processing Record 39 of Set 4 | kusk
# City not found. Skipping...
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | kosh-agach
# Processing Record 42 of Set 4 | oussouye
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | saint-jean-port-joli
# Processing Record 45 of Set 4 | hit
# Processing Record 46 of Set 4 | centralia
# Processing Record 47 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 49 of Set 4 | nara
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | flin flon
# Processing Record 2 of Set 5 | berdigestyakh
# Processing Record 3 of Set 5 | santa isabel do rio negro
# Processing Record 4 of Set 5 | olafsvik
# Processing Record 5 of Set 5 | ruston
# Processing Record 6 of Set 5 | mimongo
# Processing Record 7 of Set 5 | belyy yar
# Processing Record 8 of Set 5 | tabriz
# Processing Record 9 of Set 5 | natal
# Processing Record 10 of Set 5 | manokwari
# Processing Record 11 of Set 5 | zyryanka
# Processing Record 12 of Set 5 | uturoa
# Processing Record 13 of Set 5 | kedougou
# Processing Record 14 of Set 5 | mattru
# Processing Record 15 of Set 5 | suoyarvi
# Processing Record 16 of Set 5 | hlotse
# Processing Record 17 of Set 5 | alice springs
# Processing Record 18 of Set 5 | tomatlan
# Processing Record 19 of Set 5 | saint-georges
# Processing Record 20 of Set 5 | sabang
# Processing Record 21 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 5 | mana
# Processing Record 23 of Set 5 | kendari
# Processing Record 24 of Set 5 | saint-pierre
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | georgetown
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | touros
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | nizhneshilovka
# City not found. Skipping...
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | berlevag
# Processing Record 34 of Set 5 | amparafaravola
# Processing Record 35 of Set 5 | saskylakh
# Processing Record 36 of Set 5 | mount isa
# Processing Record 37 of Set 5 | zeya
# Processing Record 38 of Set 5 | chalons-en-champagne
# Processing Record 39 of Set 5 | portland
# Processing Record 40 of Set 5 | muros
# Processing Record 41 of Set 5 | acajutla
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | bagaces
# Processing Record 45 of Set 5 | leiyang
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | mandalgovi
# Processing Record 49 of Set 5 | airai
# Processing Record 50 of Set 5 | mareeba
# Processing Record 1 of Set 6 | moramanga
# Processing Record 2 of Set 6 | oksfjord
# Processing Record 3 of Set 6 | baturaja
# Processing Record 4 of Set 6 | saint-joseph
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | khor
# Processing Record 7 of Set 6 | novaya igirma
# Processing Record 8 of Set 6 | makakilo city
# Processing Record 9 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 6 | luanda
# Processing Record 11 of Set 6 | san-pedro
# Processing Record 12 of Set 6 | kisangani
# Processing Record 13 of Set 6 | khatanga
# Processing Record 14 of Set 6 | linjiang
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | el tigre
# Processing Record 17 of Set 6 | boz
# Processing Record 18 of Set 6 | carnarvon
# Processing Record 19 of Set 6 | ried
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | la ronge
# Processing Record 22 of Set 6 | tandil
# Processing Record 23 of Set 6 | matamoros
# Processing Record 24 of Set 6 | abbeville
# Processing Record 25 of Set 6 | sao joao da barra
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | murakami
# Processing Record 28 of Set 6 | pevek
# Processing Record 29 of Set 6 | sterling
# Processing Record 30 of Set 6 | guerrero negro
# Processing Record 31 of Set 6 | natividade
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | labuhan
# Processing Record 34 of Set 6 | neuquen
# Processing Record 35 of Set 6 | moerai
# Processing Record 36 of Set 6 | karasjok
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | trinidad
# Processing Record 39 of Set 6 | xihua
# Processing Record 40 of Set 6 | harer
# Processing Record 41 of Set 6 | camabatela
# Processing Record 42 of Set 6 | mitu
# Processing Record 43 of Set 6 | cockburn town
# Processing Record 44 of Set 6 | uvira
# Processing Record 45 of Set 6 | severo-kurilsk
# Processing Record 46 of Set 6 | chateau-thierry
# Processing Record 47 of Set 6 | narsaq
# Processing Record 48 of Set 6 | tigil
# Processing Record 49 of Set 6 | bambous virieux
# Processing Record 50 of Set 6 | terrace
# Processing Record 1 of Set 7 | fushan
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | onega
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | broken hill
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | macau
# Processing Record 8 of Set 7 | bam
# Processing Record 9 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 10 of Set 7 | inyonga
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | wajima
# Processing Record 13 of Set 7 | fukue
# Processing Record 14 of Set 7 | piney green
# Processing Record 15 of Set 7 | sakakah
# Processing Record 16 of Set 7 | ambon
# Processing Record 17 of Set 7 | boguchany
# Processing Record 18 of Set 7 | lavrentiya
# Processing Record 19 of Set 7 | naze
# Processing Record 20 of Set 7 | chingirlau
# Processing Record 21 of Set 7 | mount gambier
# Processing Record 22 of Set 7 | meridian
# Processing Record 23 of Set 7 | renfrew
# Processing Record 24 of Set 7 | tuy hoa
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | chapleau
# Processing Record 27 of Set 7 | carutapera
# Processing Record 28 of Set 7 | fort nelson
# Processing Record 29 of Set 7 | clyde river
# Processing Record 30 of Set 7 | ketchikan
# Processing Record 31 of Set 7 | bashmakovo
# Processing Record 32 of Set 7 | saurimo
# Processing Record 33 of Set 7 | fontem
# Processing Record 34 of Set 7 | le port
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | akyab
# Processing Record 37 of Set 7 | los llanos de aridane
# Processing Record 38 of Set 7 | hofn
# Processing Record 39 of Set 7 | rudbar
# Processing Record 40 of Set 7 | bouar
# Processing Record 41 of Set 7 | galveston
# Processing Record 42 of Set 7 | porto santo
# Processing Record 43 of Set 7 | rawson
# Processing Record 44 of Set 7 | machali
# Processing Record 45 of Set 7 | huatulco
# Processing Record 46 of Set 7 | shimoda
# Processing Record 47 of Set 7 | severobaykalsk
# Processing Record 48 of Set 7 | angoram
# Processing Record 49 of Set 7 | sistranda
# Processing Record 50 of Set 7 | torrington
# Processing Record 1 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 2 of Set 8 | kontagora
# Processing Record 3 of Set 8 | acapulco
# Processing Record 4 of Set 8 | guayaramerin
# Processing Record 5 of Set 8 | mehriz
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | sainte-rose
# Processing Record 8 of Set 8 | turukhansk
# Processing Record 9 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 8 | kieta
# Processing Record 11 of Set 8 | lingao
# Processing Record 12 of Set 8 | handwara
# City not found. Skipping...
# Processing Record 13 of Set 8 | flinders
# Processing Record 14 of Set 8 | montego bay
# Processing Record 15 of Set 8 | maine-soroa
# Processing Record 16 of Set 8 | byron bay
# Processing Record 17 of Set 8 | straumen
# Processing Record 18 of Set 8 | ambulu
# Processing Record 19 of Set 8 | mamou
# Processing Record 20 of Set 8 | zaton
# Processing Record 21 of Set 8 | kirkland lake
# Processing Record 22 of Set 8 | ucluelet
# Processing Record 23 of Set 8 | weligama
# Processing Record 24 of Set 8 | nemuro
# Processing Record 25 of Set 8 | staines
# Processing Record 26 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 8 | bermejillo
# Processing Record 28 of Set 8 | caraballeda
# Processing Record 29 of Set 8 | primorsk
# Processing Record 30 of Set 8 | kimberley
# Processing Record 31 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 8 | karratha
# Processing Record 33 of Set 8 | hualmay
# Processing Record 34 of Set 8 | disna
# Processing Record 35 of Set 8 | yerbogachen
# Processing Record 36 of Set 8 | dubrovnik
# Processing Record 37 of Set 8 | kolyvan
# Processing Record 38 of Set 8 | puro
# Processing Record 39 of Set 8 | fenoarivo
# Processing Record 40 of Set 8 | longyan
# Processing Record 41 of Set 8 | ilmajoki
# Processing Record 42 of Set 8 | husavik
# Processing Record 43 of Set 8 | ilesha
# Processing Record 44 of Set 8 | el porvenir
# Processing Record 45 of Set 8 | rebrikha
# Processing Record 46 of Set 8 | langsa
# Processing Record 47 of Set 8 | okato
# Processing Record 48 of Set 8 | southend-on-sea
# Processing Record 49 of Set 8 | verkhnyaya inta
# Processing Record 50 of Set 8 | provideniya
# Processing Record 1 of Set 9 | umm kaddadah
# Processing Record 2 of Set 9 | port macquarie
# Processing Record 3 of Set 9 | laguna
# Processing Record 4 of Set 9 | walvis bay
# Processing Record 5 of Set 9 | chaykovskiy
# Processing Record 6 of Set 9 | makaryev
# Processing Record 7 of Set 9 | ginda
# Processing Record 8 of Set 9 | odweyne
# Processing Record 9 of Set 9 | fairbanks
# Processing Record 10 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 9 | nalut
# Processing Record 12 of Set 9 | itaituba
# Processing Record 13 of Set 9 | hambantota
# Processing Record 14 of Set 9 | fort wellington
# Processing Record 15 of Set 9 | okhotsk
# Processing Record 16 of Set 9 | leshukonskoye
# Processing Record 17 of Set 9 | vuktyl
# Processing Record 18 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 9 | leirvik
# Processing Record 20 of Set 9 | beloha
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | grahamstown
# Processing Record 23 of Set 9 | dourbali
# Processing Record 24 of Set 9 | alyangula
# Processing Record 25 of Set 9 | meteti
# Processing Record 26 of Set 9 | sakhon nakhon
# Processing Record 27 of Set 9 | kashan
# Processing Record 28 of Set 9 | ukiah
# Processing Record 29 of Set 9 | skoghall
# Processing Record 30 of Set 9 | leesburg
# Processing Record 31 of Set 9 | bambanglipuro
# Processing Record 32 of Set 9 | itarema
# Processing Record 33 of Set 9 | spetsai
# City not found. Skipping...
# Processing Record 34 of Set 9 | ambovombe
# Processing Record 35 of Set 9 | nioro
# Processing Record 36 of Set 9 | moa
# Processing Record 37 of Set 9 | gorontalo
# Processing Record 38 of Set 9 | mwanza
# Processing Record 39 of Set 9 | palmer
# Processing Record 40 of Set 9 | kachiry
# Processing Record 41 of Set 9 | burica
# City not found. Skipping...
# Processing Record 42 of Set 9 | uppsala
# Processing Record 43 of Set 9 | pacific grove
# Processing Record 44 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 9 | san patricio
# Processing Record 46 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 9 | evensk
# Processing Record 48 of Set 9 | katsuura
# Processing Record 49 of Set 9 | bodden town
# Processing Record 50 of Set 9 | paso de los toros
# Processing Record 1 of Set 10 | meulaboh
# Processing Record 2 of Set 10 | dracena
# Processing Record 3 of Set 10 | gizo
# Processing Record 4 of Set 10 | ulladulla
# Processing Record 5 of Set 10 | jardim
# Processing Record 6 of Set 10 | sobolevo
# Processing Record 7 of Set 10 | havelock
# Processing Record 8 of Set 10 | lasa
# Processing Record 9 of Set 10 | kirakira
# Processing Record 10 of Set 10 | monduli
# Processing Record 11 of Set 10 | singaraja
# Processing Record 12 of Set 10 | yefira
# City not found. Skipping...
# Processing Record 13 of Set 10 | egvekinot
# Processing Record 14 of Set 10 | pervoye maya
# Processing Record 15 of Set 10 | kochubey
# Processing Record 16 of Set 10 | jaicos
# Processing Record 17 of Set 10 | chimore
# Processing Record 18 of Set 10 | porto novo
# Processing Record 19 of Set 10 | yeppoon
# Processing Record 20 of Set 10 | sambava
# Processing Record 21 of Set 10 | abu dhabi
# Processing Record 22 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 10 | pinega
# Processing Record 24 of Set 10 | tecoanapa
# Processing Record 25 of Set 10 | torquay
# Processing Record 26 of Set 10 | hima
# Processing Record 27 of Set 10 | comodoro rivadavia
# Processing Record 28 of Set 10 | port hedland
# Processing Record 29 of Set 10 | nea iraklitsa
# Processing Record 30 of Set 10 | broome
# Processing Record 31 of Set 10 | margate
# Processing Record 32 of Set 10 | mollendo
# Processing Record 33 of Set 10 | kapuskasing
# Processing Record 34 of Set 10 | camopi
# Processing Record 35 of Set 10 | ossora
# Processing Record 36 of Set 10 | salihorsk
# Processing Record 37 of Set 10 | koster
# Processing Record 38 of Set 10 | surt
# Processing Record 39 of Set 10 | moron
# Processing Record 40 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 10 | cockeysville
# Processing Record 42 of Set 10 | jardim de piranhas
# Processing Record 43 of Set 10 | esmeralda
# Processing Record 44 of Set 10 | tual
# Processing Record 45 of Set 10 | prigorodka
# Processing Record 46 of Set 10 | sibay
# Processing Record 47 of Set 10 | cheney
# Processing Record 48 of Set 10 | nueva granada
# Processing Record 49 of Set 10 | vastervik
# City not found. Skipping...
# Processing Record 50 of Set 10 | dunedin
# Processing Record 1 of Set 11 | sabae
# Processing Record 2 of Set 11 | atar
# Processing Record 3 of Set 11 | sorland
# Processing Record 4 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 5 of Set 11 | sitka
# Processing Record 6 of Set 11 | mataram
# Processing Record 7 of Set 11 | bundaberg
# Processing Record 8 of Set 11 | tabou
# Processing Record 9 of Set 11 | aklavik
# Processing Record 10 of Set 11 | sargatskoye
# Processing Record 11 of Set 11 | skjervoy
# Processing Record 12 of Set 11 | benguela
# Processing Record 13 of Set 11 | taltal
# Processing Record 14 of Set 11 | mocuba
# Processing Record 15 of Set 11 | invermere
# Processing Record 16 of Set 11 | ixtapa
# Processing Record 17 of Set 11 | palimbang
# Processing Record 18 of Set 11 | kitimat
# Processing Record 19 of Set 11 | cah ab
# City not found. Skipping...
# Processing Record 20 of Set 11 | ovsyanka
# Processing Record 21 of Set 11 | kavaratti
# Processing Record 22 of Set 11 | porto de moz
# Processing Record 23 of Set 11 | peleduy
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | changping
# Processing Record 26 of Set 11 | campo maior
# Processing Record 27 of Set 11 | kargala
# Processing Record 28 of Set 11 | innisfail
# Processing Record 29 of Set 11 | harper
# Processing Record 30 of Set 11 | llano de piedra
# Processing Record 31 of Set 11 | caravelas
# Processing Record 32 of Set 11 | colquechaca
# Processing Record 33 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 34 of Set 11 | san cristobal
# Processing Record 35 of Set 11 | jaciara
# Processing Record 36 of Set 11 | felanitx
# Processing Record 37 of Set 11 | cienaga de flores
# City not found. Skipping...
# Processing Record 38 of Set 11 | glenwood springs
# Processing Record 39 of Set 11 | san joaquin
# Processing Record 40 of Set 11 | chivay
# Processing Record 41 of Set 11 | mpongwe
# Processing Record 42 of Set 11 | pirenopolis
# Processing Record 43 of Set 11 | yanam
# Processing Record 44 of Set 11 | shambu
# Processing Record 45 of Set 11 | kaz
# Processing Record 46 of Set 11 | kumluca
# Processing Record 47 of Set 11 | lovosice
# Processing Record 48 of Set 11 | umm lajj
# Processing Record 49 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 50 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 12 | snyder
# Processing Record 2 of Set 12 | kampot
# Processing Record 3 of Set 12 | aktash
# Processing Record 4 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 12 | caxito
# Processing Record 6 of Set 12 | belle fourche
# Processing Record 7 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 12 | oranjemund
# Processing Record 9 of Set 12 | kuytun
# Processing Record 10 of Set 12 | kuala lipis
# Processing Record 11 of Set 12 | praia
# Processing Record 12 of Set 12 | opuwo
# Processing Record 13 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 12 | skibbereen
# Processing Record 16 of Set 12 | syasstroy
# Processing Record 17 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 12 | namatanai
# Processing Record 19 of Set 12 | sidrolandia
# Processing Record 20 of Set 12 | eydhafushi
# Processing Record 21 of Set 12 | mahibadhoo
# Processing Record 22 of Set 12 | saint george
# Processing Record 23 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 12 | murdochville
# Processing Record 25 of Set 12 | ondangwa
# Processing Record 26 of Set 12 | zlobin
# Processing Record 27 of Set 12 | pombas
# Processing Record 28 of Set 12 | miri
# Processing Record 29 of Set 12 | vanimo
# Processing Record 30 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 12 | howard springs
# Processing Record 32 of Set 12 | paamiut
# Processing Record 33 of Set 12 | tamluk
# Processing Record 34 of Set 12 | ngunguru
# Processing Record 35 of Set 12 | stromness
# Processing Record 36 of Set 12 | banda aceh
# Processing Record 37 of Set 12 | almaznyy
# Processing Record 38 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 39 of Set 12 | port keats
# Processing Record 40 of Set 12 | lynn haven
# Processing Record 41 of Set 12 | beira
# Processing Record 42 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 12 | prokhorovka
# Processing Record 44 of Set 12 | djambala
# Processing Record 45 of Set 12 | saint-francois
# Processing Record 46 of Set 12 | kandalaksha
# Processing Record 47 of Set 12 | tucuman
# Processing Record 48 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 12 | northam
# Processing Record 50 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 13 | zalantun
# Processing Record 2 of Set 13 | iquique
# Processing Record 3 of Set 13 | te anau
# Processing Record 4 of Set 13 | kharagpur
# Processing Record 5 of Set 13 | lianzhou
# Processing Record 6 of Set 13 | talas
# Processing Record 7 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 13 | ripky
# Processing Record 9 of Set 13 | ponta delgada
# Processing Record 10 of Set 13 | bilibino
# Processing Record 11 of Set 13 | nishihara
# Processing Record 12 of Set 13 | nyurba
# Processing Record 13 of Set 13 | esna
# Processing Record 14 of Set 13 | panuco
# Processing Record 15 of Set 13 | bardiyah
# Processing Record 16 of Set 13 | inhambupe
# Processing Record 17 of Set 13 | ostrovnoy
# Processing Record 18 of Set 13 | doha
# Processing Record 19 of Set 13 | maldonado
# Processing Record 20 of Set 13 | teguise
# Processing Record 21 of Set 13 | bathsheba
# Processing Record 22 of Set 13 | salalah
# Processing Record 23 of Set 13 | port blair
# Processing Record 24 of Set 13 | morant bay
# Processing Record 25 of Set 13 | vanderhoof
# Processing Record 26 of Set 13 | college
# Processing Record 27 of Set 13 | pervomayskiy
# Processing Record 28 of Set 13 | topeka
# Processing Record 29 of Set 13 | ozernovskiy
# Processing Record 30 of Set 13 | rio gallegos
# Processing Record 31 of Set 13 | finschhafen
# Processing Record 32 of Set 13 | talcahuano
# Processing Record 33 of Set 13 | mogadishu
# Processing Record 34 of Set 13 | dwarka
# Processing Record 35 of Set 13 | batemans bay
# Processing Record 36 of Set 13 | durazno
# Processing Record 37 of Set 13 | rabat
# Processing Record 38 of Set 13 | vestmanna
# Processing Record 39 of Set 13 | brae
# Processing Record 40 of Set 13 | kahului
# Processing Record 41 of Set 13 | beaverlodge
# Processing Record 42 of Set 13 | avigliano
# Processing Record 43 of Set 13 | khash
# Processing Record 44 of Set 13 | nha trang
# Processing Record 45 of Set 13 | lamu
# Processing Record 46 of Set 13 | agboville
# Processing Record 47 of Set 13 | torma
# Processing Record 48 of Set 13 | avallon
# Processing Record 49 of Set 13 | chadiza
# Processing Record 50 of Set 13 | general pico
# Processing Record 1 of Set 14 | necochea
# Processing Record 2 of Set 14 | chapais
# Processing Record 3 of Set 14 | goderich
# Processing Record 4 of Set 14 | denpasar
# Processing Record 5 of Set 14 | kingman
# Processing Record 6 of Set 14 | puerto escondido
# Processing Record 7 of Set 14 | kushiro
# Processing Record 8 of Set 14 | vanavara
# Processing Record 9 of Set 14 | polis
# Processing Record 10 of Set 14 | alekseyevsk
# Processing Record 11 of Set 14 | gao
# Processing Record 12 of Set 14 | ewa beach
# Processing Record 13 of Set 14 | praxedis guerrero
# Processing Record 14 of Set 14 | saint anthony
# Processing Record 15 of Set 14 | tahta
# Processing Record 16 of Set 14 | jiexiu
# Processing Record 17 of Set 14 | cervo
# Processing Record 18 of Set 14 | whitecourt
# Processing Record 19 of Set 14 | thinadhoo
# Processing Record 20 of Set 14 | cozumel
# Processing Record 21 of Set 14 | chibuto
# Processing Record 22 of Set 14 | changli
# Processing Record 23 of Set 14 | bathurst
# Processing Record 24 of Set 14 | sao gabriel da cachoeira
# Processing Record 25 of Set 14 | tautira
# Processing Record 26 of Set 14 | ponazyrevo
# Processing Record 27 of Set 14 | mvomero
# Processing Record 28 of Set 14 | fernie
# Processing Record 29 of Set 14 | corinto
# Processing Record 30 of Set 14 | olimpia
# Processing Record 31 of Set 14 | nantucket
# Processing Record 32 of Set 14 | morgan city
# Processing Record 33 of Set 14 | ulaanbaatar
# Processing Record 34 of Set 14 | gobabis
# Processing Record 35 of Set 14 | turayf
# Processing Record 36 of Set 14 | pandan
# Processing Record 37 of Set 14 | mariental
# Processing Record 38 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 14 | yarmouth
# Processing Record 40 of Set 14 | allonnes
# Processing Record 41 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 14 | nelson bay
# Processing Record 43 of Set 14 | conceicao do araguaia
# Processing Record 44 of Set 14 | smidovich
# Processing Record 45 of Set 14 | voh
# Processing Record 46 of Set 14 | itapipoca
# Processing Record 47 of Set 14 | encheng
# Processing Record 48 of Set 14 | kanniyakumari
# Processing Record 49 of Set 14 | taywarah
# Processing Record 50 of Set 14 | carballo
# Processing Record 1 of Set 15 | dombarovskiy
# Processing Record 2 of Set 15 | isangel
# Processing Record 3 of Set 15 | atsiki
# City not found. Skipping...
# Processing Record 4 of Set 15 | songea
# Processing Record 5 of Set 15 | muroto
# Processing Record 6 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 7 of Set 15 | pafos
# Processing Record 8 of Set 15 | maumere
# Processing Record 9 of Set 15 | roebourne
# Processing Record 10 of Set 15 | humaita
# Processing Record 11 of Set 15 | cedral
# Processing Record 12 of Set 15 | jumla
# Processing Record 13 of Set 15 | porosozero
# Processing Record 14 of Set 15 | nouadhibou
# Processing Record 15 of Set 15 | tilichiki
# Processing Record 16 of Set 15 | sur
# Processing Record 17 of Set 15 | bayan
# Processing Record 18 of Set 15 | hongjiang
# Processing Record 19 of Set 15 | nusaybin
# Processing Record 20 of Set 15 | verkhniy ufaley
# Processing Record 21 of Set 15 | monte patria
# Processing Record 22 of Set 15 | russell
# Processing Record 23 of Set 15 | palasa
# Processing Record 24 of Set 15 | truckee
# Processing Record 25 of Set 15 | ust-nera
# Processing Record 26 of Set 15 | magole
# Processing Record 27 of Set 15 | daru
# Processing Record 28 of Set 15 | ust-barguzin
# Processing Record 29 of Set 15 | port lincoln
# Processing Record 30 of Set 15 | vila franca do campo
# Processing Record 31 of Set 15 | amahai
# Processing Record 32 of Set 15 | omboue
# Processing Record 33 of Set 15 | rafraf
# Processing Record 34 of Set 15 | smithers
# Processing Record 35 of Set 15 | sibolga
# Processing Record 36 of Set 15 | zhuzhou
# Processing Record 37 of Set 15 | xuddur
# Processing Record 38 of Set 15 | qandala
# Processing Record 39 of Set 15 | rio grande
# Processing Record 40 of Set 15 | kalayaan
# Processing Record 41 of Set 15 | kolpashevo
# Processing Record 42 of Set 15 | anloga
# Processing Record 43 of Set 15 | conceicao da barra
# Processing Record 44 of Set 15 | najran
# Processing Record 45 of Set 15 | santa vitoria do palmar
# Processing Record 46 of Set 15 | andra
# Processing Record 47 of Set 15 | villazon
# Processing Record 48 of Set 15 | sortavala
# Processing Record 49 of Set 15 | machilipatnam
# Processing Record 50 of Set 15 | tiznit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     41.11        87          75
# 1   Yellowknife      CA  62.4560 -114.3525     43.03        76          90
# 2  Puerto Ayora      EC  -0.7393  -90.3518     68.92        87          63
# 3        Avarua      CK -21.2078 -159.7750     75.25        57          40
# 4   Port Alfred      ZA -33.5906   26.8910     60.22        84         100
# 5       Karaton      ID  -6.3424  106.1045     87.96        60          98
# 6        Torbay      CA  47.6666  -52.7314     54.88        91          90
# 7      Nakhodka      RU  42.8333  132.8947     59.99        88          99
# 8          Chuy      UY -33.6971  -53.4616     54.86        95          69
# 9       Rikitea      PF -23.1203 -134.9692     74.03        78         100
#
#    Wind Speed Current Description
# 0        2.30          light rain
# 1        3.33     overcast clouds
# 2        7.72       broken clouds
# 3        5.75    scattered clouds
# 4       12.41     overcast clouds
# 5        6.73     overcast clouds
# 6       12.66     overcast clouds
# 7        1.16     overcast clouds
# 8        5.68       broken clouds
# 9       23.31     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
